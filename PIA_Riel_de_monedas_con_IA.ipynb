# %% [markdown]
# # ACTIVIDAD 3 PROYECTO FINAL

# %%
import tensorflow as tf
import os
# !unzip MONEDAS.zip

IMG_SIZE = (64, 64)   # tamaño de entrada
BATCH_SIZE = 32

# Define la ruta a tu directorio de entrenamiento
train_dir = "/content/MONEDAS/test"

# Obtén el número de clases a partir del número de subdirectorios en el directorio de entrenamiento
num_classes = len([name for name in os.listdir(train_dir) if os.path.isdir(os.path.join(train_dir, name))])

# Definir el modelo (ejemplo simple)
model = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=IMG_SIZE + (3,)),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    # Usa num_classes para definir el número de unidades en la capa de salida
    tf.keras.layers.Dense(num_classes, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/MONEDAS/train",
    labels="inferred",
    label_mode="categorical",
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    shuffle=True,
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/MONEDAS/valid",
    labels="inferred",
    label_mode="categorical",
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    shuffle=False,
)

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/MONEDAS/test",
    labels="inferred",
    label_mode="categorical",
    batch_size=BATCH_SIZE,
    image_size=IMG_SIZE,
    shuffle=False,
)

AUTOTUNE = tf.data.AUTOTUNE

# 1) Normalización
normalization_layer = tf.keras.layers.Rescaling(1./255)

train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)
val_ds   = val_ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)
test_ds  = test_ds.map(lambda x, y: (normalization_layer(x), y), num_parallel_calls=AUTOTUNE)

# 2) Prefetch para solapar cargas y entrenamiento
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds   = val_ds.prefetch(buffer_size=AUTOTUNE)
test_ds  = test_ds.prefetch(buffer_size=AUTOTUNE)

history = model.fit(
    train_ds,
    epochs=20,
    validation_data=val_ds,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True),
        tf.keras.callbacks.ModelCheckpoint("mejor_modelo.h5", save_best_only=True, monitor="val_accuracy")
    ]
)

# Evaluar en test
loss, acc = model.evaluate(test_ds)
print(f"Precisión en test: {acc*100:.2f}%")

model.save("clasificador_monedas.h5")
# Para inferencia luego:
# from tensorflow.keras.models import load_model
# modelo = load_model("clasificador_monedas.h5")
# Out:
# Archive:  MONEDAS.zip
#    creating: MONEDAS/
#   inflating: MONEDAS/data.yaml
#   inflating: MONEDAS/README.dataset.txt
#   inflating: MONEDAS/README.roboflow.txt
#    creating: MONEDAS/test/
#    creating: MONEDAS/test/CENTAVO/
#   inflating: MONEDAS/test/CENTAVO/CENTAVO_1747788400294_jpg.rf.d754518a97f7361fe9ef93270635554e.jpg
#   inflating: MONEDAS/test/CENTAVO/CENTAVO_1747788403796_jpg.rf (1).jpg
#   inflating: MONEDAS/test/CENTAVO/CENTAVO_1747788403796_jpg.rf (2).jpg
#   inflating: MONEDAS/test/CENTAVO/CENTAVO_1747788403796_jpg.rf (3).jpg
#   inflating: MONEDAS/test/CENTAVO/CENTAVO_1747788403796_jpg.rf (4).jpg
#   inflating: MONEDAS/valid/PESO10/PESO10_1747781448939_jpg.rf (3).jpg
#   inflating: MONEDAS/valid/PESO10/PESO10_1747781448939_jpg.rf (4).jpg
#   inflating: MONEDAS/valid/PESO10/PESO10_1747781448939_jpg.rf (5).jpg
#   inflating: MONEDAS/valid/PESO10/PESO10_1747781448939_jpg.rf (6).jpg
#   inflating: MONEDAS/valid/PESO10/PESO10_1747781448939_jpg.rf (7).jpg
#   inflating: MONEDAS/valid/PESO10/PESO10_1747781448939_jpg.rf (8).jpg
#   inflating: MONEDAS/valid/PESO10/PESO10_1747781448939_jpg.rf (9).jpg
#    creating: MONEDAS/valid/PESO2/
#   inflating: MONEDAS/valid/PESO2/PESO2_1747783740588_jpg.rf (1).jpg
#   inflating: MONEDAS/valid/PESO2/PESO2_1747783740588_jpg.rf (10).jpg
#   inflating: MONEDAS/valid/PESO2/PESO2_1747783740588_jpg.rf (11).jpg
#   inflating: MONEDAS/valid/PESO2/PESO2_1747783740588_jpg.rf (12).jpg
#   inflating: MONEDAS/valid/PESO2/PESO2_1747783740588_jpg.rf (13).jpg
#   inflating: MONEDAS/valid/PESO2/PESO2_1747783740588_jpg.rf (14).jpg
#   inflating: MONEDAS/valid/PESO2/PESO2_1747783740588_jpg.rf (2).jpg
#   inflating: MONEDAS/valid/PESO2/PESO2_1747783740588_jpg.rf (3).jpg
#   inflating: MONEDAS/valid/PESO2/PESO2_1747783740588_jpg.rf (4).jpg
#   inflating: MONEDAS/valid/PESO2/PESO2_1747783740588_jpg.rf (5).jpg
#   inflating: MONEDAS/valid/PESO2/PESO2_1747783740588_jpg.rf (6).jpg
#   inflating: MONEDAS/valid/PESO2/PESO2_1747783740588_jpg.rf (7).jpg
#   inflating: MONEDAS/valid/PESO2/PESO2_1747783740588_jpg.rf (8).jpg
#   inflating: MONEDAS/valid/PESO2/PESO2_1747783740588_jpg.rf (9).jpg
#    creating: MONEDAS/valid/PESO5/
#   inflating: MONEDAS/valid/PESO5/PESO5_1747783450097_jpg.rf (1).jpg
#   inflating: MONEDAS/valid/PESO5/PESO5_1747783450097_jpg.rf (10).jpg
#   inflating: MONEDAS/valid/PESO5/PESO5_1747783450097_jpg.rf (11).jpg
#   inflating: MONEDAS/valid/PESO5/PESO5_1747783450097_jpg.rf (12).jpg
#   inflating: MONEDAS/valid/PESO5/PESO5_1747783450097_jpg.rf (13).jpg
#   inflating: MONEDAS/valid/PESO5/PESO5_1747783450097_jpg.rf (2).jpg
#   inflating: MONEDAS/valid/PESO5/PESO5_1747783450097_jpg.rf (3).jpg
#   inflating: MONEDAS/valid/PESO5/PESO5_1747783450097_jpg.rf (4).jpg
#   inflating: MONEDAS/valid/PESO5/PESO5_1747783450097_jpg.rf (5).jpg
#   inflating: MONEDAS/valid/PESO5/PESO5_1747783450097_jpg.rf (6).jpg
#   inflating: MONEDAS/valid/PESO5/PESO5_1747783450097_jpg.rf (7).jpg
#   inflating: MONEDAS/valid/PESO5/PESO5_1747783450097_jpg.rf (8).jpg
#   inflating: MONEDAS/valid/PESO5/PESO5_1747783450097_jpg.rf (9).jpg
# Found 243 files belonging to 5 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
#